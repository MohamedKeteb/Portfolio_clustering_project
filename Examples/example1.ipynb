# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
## we make some manipulations to correctly import module1

import os
import sys

# on a obtenu le chemin absolu vers notre répertoire en utilisant
# le terminal (ls, pwd, cd)
module_1_directory = '/Users/khelifanail/Documents/GitHub/Portfolio_clustering_project/code'

# Ajouter le chemin du répertoire 'code' au chemin de recherche Python
sys.path.append(module_1_directory)

# Maintenant, vous pouvez importer module1
import module1

# %%
stock_symbols = ["AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "TSLA", "META", "UNH", "JPM", "JNJ", "XOM", "V", "PG", "AVGO", "LLY", "HD", "MA", "CVX", "MRK", "ABBV", "PEP", "COST", "ADBE", "KO", "WMT", "BAC", "CSCO", "MCD", "TMO", "CRM", "ACN", "PFE", "NFLX", "CMCSA", "ABT", "LIN", "AMD", "ORCL", "DHR", "WFC", "DIS", "TXN", "PM", "CAT", "INTC", "NEE", "UNP", "INTU", "COP", "VZ", "LOW", "NKE", "QCOM", "UPS", "IBM", "BA", "BMY", "HON", "SPGI", "AMAT", "RTX", "AMGN", "GE", "SBUX", "GS", "MS", "DE", "NOW", "PLD", "MDT", "ELV", "ISRG", "BLK", "BKNG", "ADP", "MDLZ", "LMT", "T", "TJX", "AXP", "SCHW", "ADI", "CVS", "MMC", "GILD", "LRCX", "SYK", "VRTX", "C", "AMT", "ETN", "CI", "CB", "ZTS", "REGN", "SLB", "MO", "TMUS", "FI", "EOG", "BDX", "MU", "PGR", "SO", "BSX", "CME", "PANW", "PYPL", "EQIX", "DUK", "ITW", "KLAC", "SNPS", "CSX", "ATVI", "AON", "SHW", "CL", "NOC", "CDNS", "ICE", "APD", "FCX", "FDX", "TGT", "HUM", "WM", "MMM", "MCK", "MPC", "ORLY", "HCA", "NXPI", "USB", "EMR", "PXD", "PH", "PNC", "CMG", "MCO", "APH", "ROP", "MAR", "NSC", "GM", "F", "GD", "PSX", "MCHP", "FTNT", "CARR", "EW", "MSI", "AJG", "TT", "DXCM", "ADM", "TDG", "AZO", "VLO", "CCI", "PSA", "OXY", "SRE", "ECL", "TEL", "AIG", "ON", "PCAR", "MNST", "ANET", "CHTR", "GIS", "ADSK", "STZ", "NUE", "MSCI", "KMB", "CTAS", "COF", "TFC", "JCI", "AFL", "D", "IDXX", "AEP", "WMB", "WELL", "MET", "EXC", "HLT", "IQV", "PAYX", "EL", "CTVA", "O", "TRV", "ROST"]

n_stocks = len(stock_symbols) # number of stocks = 198

start = "2022-01-01" # start date
end = "2022-12-01" # end date

df = pd.DataFrame(yf.download(stock_symbols, start, end)) # data on the 198 assets
data = np.log(df["Close"]/df["Open"]).transpose() # compute the returns of these assets
data = data.dropna()
# Out:
# [*********************100%%**********************]  198 of 198 completed

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),   # Étape de standardisation
    ('kmeans', KMeans(n_clusters=5)) # Étape K-Means avec 3 clusters
])

pipeline.fit(data)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Pipeline(steps=[('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=5))])

# %%
labels = pipeline.named_steps['kmeans'].labels_
pd.value_counts(labels)
# Out:
# /var/folders/q2/wg5gyfhj2r9cd97zfmckktvw0000gn/T/ipykernel_30665/1173553783.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(labels)
# 3    90
# 1    63
# 0    21
# 4    14
# 2    10
# Name: count, dtype: int64

# %%
model = KMeans(n_clusters=5)
multiple_clustering = module1.multiple_clusterings(n_repeat=100, data=data, model=model)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
multiple_clustering.head()
# Out:
#       Clustering n°1  Clustering n°2  Clustering n°3  Clustering n°4  \
# AAPL               4               2               2               1
# ABBV               3               1               0               2
# ABT                4               1               2               3
# ACN                4               3               2               3
# ADBE               1               2               1               1
#
#       Clustering n°5  Clustering n°6  Clustering n°7  Clustering n°8  \
# AAPL               3               0               1               4
# ABBV               2               4               0               0
# ABT                4               1               1               0
# ACN                4               1               1               3
# ADBE               3               0               2               4
#
#       Clustering n°9  Clustering n°10  ...  Clustering n°91  Clustering n°92  \
# ...

# %%
cluster_composition = module1.cluster_composition(multiple_clustering)

# %%
cluster_composition.head(1)
# Out:
#                                               Clustering n°1  \
# Cluster 1  [AAPL, ABT, ACN, ADP, AIG, AJG, AON, APD, APH,...
#
#                                               Clustering n°2  \
# Cluster 1  [AAPL, ADBE, ADSK, AMZN, ANET, CDNS, CMG, CRM,...
#
#                                               Clustering n°3  \
# Cluster 1  [AAPL, ABT, ACN, ADP, AIG, AJG, AON, APD, APH,...
#
#                                               Clustering n°4  \
# Cluster 1  [AAPL, ADBE, ADSK, AMZN, ANET, CDNS, CMG, CRM,...
#
#                                               Clustering n°5  \
# Cluster 1  [AAPL, ADBE, ADI, ADSK, AMAT, AMD, AMZN, ANET,...
#
#                                               Clustering n°6  \
# Cluster 1  [AAPL, ADBE, ADSK, AMZN, ANET, BKNG, CDNS, CMG...
#
#                                               Clustering n°7  \
# Cluster 1  [AAPL, ABT, ACN, ADP, AIG, AJG, AON, APD, APH,...
#
#                                               Clustering n°8  \
# ...

# %% [markdown]
# # Remarque :
#
# On ne récupère ici qu'une seule colonne pour pouvoir appliquer la fonction **cluster_portfolio_return** (dans module1.py) qui ne s'applique qu'à un clustering.
#
# Il faut coder une nouvelle routine reposant sur **cluster_portfolio_return** qui prend en argument un objet de format similaire à celui rendu par **cluster_composition** et qui itère sur le nombre de répétitions (*n_repeat*) pour rendre un objet de *3 dimensions* (rendement d'un micro-portefeuille, temps et nombre de simulations).

# %%
C = cluster_composition.loc[:, 'Clustering n°1']

# %% [markdown]
# # Remarque :
#
# 1. N'ayant pas encore réfléchi sur une manière de calculer les poids, on prend une distribution **uniforme** sur l'ensemble des actifs.
#
# 2. Faire très attention au format du vecteur de poids ! C'est un objet de type **pandas.DataFrame** en ligne (donc **.transpose()**)

# %%
weights = pd.DataFrame(np.arange(1, n_stocks + 1)/sum(np.arange(1, n_stocks + 1))).transpose()

# %%
data.index
# Out:
# Index(['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK',
#        'AEP',
#        ...
#        'VLO', 'VRTX', 'VZ', 'WELL', 'WFC', 'WM', 'WMB', 'WMT', 'XOM', 'ZTS'],
#       dtype='object', length=198)

# %%
micro_portfolio1 = module1.cluster_portfolio_return(C, weights, data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/khelifanail/Documents/GitHub/Portfolio_clustering_project/Examples/example1.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/khelifanail/Documents/GitHub/Portfolio_clustering_project/Examples/example1.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> micro_portfolio1 = module1.cluster_portfolio_return(C, weights, data)
#
# File ~/Documents/GitHub/Portfolio_clustering_project/code/module1.py:188, in cluster_portfolio_return(cluster_composition, weights_matrix, return_data)
#     160 def cluster_portfolio_return(cluster_composition, weights_matrix, return_data):
#     161     '''
#     162     ----------------------------------------------------------------
#     163     GENERAL IDEA : compute the return of a portfolio composed of
#    (...)
#     185     ----------------------------------------------------------------
# ...
