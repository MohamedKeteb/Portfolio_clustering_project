# ZTS    -0.008939    0.001896    0.040041
#
# [496 rows x 230 columns]

# %%
model = KNeighborsClassifier(n_neighbors=5)
model_name = 'knn'

# %%
# à revoir 
n_neighbors = 5  

pipeline = Pipeline([
    ('scaler', StandardScaler()),   
    ('knn', KNeighborsClassifier(n_neighbors=n_neighbors))  
])


labels = data.index
pipeline.fit(data, labels) 
predicted_labels = pipeline.predict(data)

predicted_labels
# Out:
# array(['A', 'AAL', 'AAPL', 'ABBV', 'ABNB', 'ABT', 'ACGL', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADBE', 'AEE', 'AEE', 'AES', 'AFL', 'AIG',
#        'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'AFL', 'ALLE', 'AMAT',
#        'AMCR', 'AMD', 'AME', 'AMGN', 'AFL', 'AMT', 'AAPL', 'ANET', 'ANSS',
#        'AJG', 'AME', 'APA', 'AME', 'APH', 'APTV', 'ARE', 'AEE', 'AVB',
#        'ADI', 'AMCR', 'AEE', 'ANSS', 'AXP', 'AZO', 'ALK', 'BAC', 'AMCR',
#        'BAX', 'BBWI', 'BBY', 'ABT', 'BEN', 'ADM', 'AMGN', 'A', 'BAC',
#        'AXP', 'BKR', 'APH', 'ABBV', 'ADP', 'AJG', 'ABT', 'BWA', 'BEN',
#        'ARE', 'BAC', 'CAG', 'CAH', 'AME', 'CAT', 'CB', 'AJG', 'APH',
#        'AMT', 'AAL', 'CDAY', 'ANSS', 'AME', 'CE', 'BG', 'CFG', 'CHD',
#        'CHRW', 'ABT', 'CI', 'CB', 'CL', 'CHD', 'CFG', 'ABT', 'CME', 'APH',
#        'AFL', 'AEE', 'CI', 'AEE', 'AXP', 'ABT', 'COP', 'AMGN', 'ADP',
#        'CAG', 'APH', 'AVB', 'A', 'ADBE', 'ADP', 'APH', 'CSX', 'AME',
#        'CTLT', 'COP', 'ADP', 'AFL', 'AFL', 'COP', 'BKNG', 'AEE', 'AAL',
#        'DD', 'CAT', 'AXP', 'DG', 'ABT', 'DHI', 'A', 'APH', 'CCI', 'AZO',
#        'DOV', 'DD', 'DPZ', 'APH', 'AEE', 'AEE', 'CVS', 'COP', 'ANSS',
#        'ABT', 'CTSH', 'AME', 'AEE', 'APH', 'ACGL', 'AEE', 'APH', 'CI',
#        'DD', 'AME', 'ENPH', 'COP', 'ANSS', 'AMT', 'AVB', 'CTRA', 'AEE',
#        'AVB', 'AME', 'AEE', 'AMZN', 'DTE', 'BSX', 'AEE', 'APH', 'BKNG',
#        'EQR', 'BWA', 'COP', 'AME', 'AMP', 'CTAS', 'FDX', 'AEE', 'APH',
#        'APH', 'FICO', 'FI', 'CFG', 'APH', 'CTVA', 'FOX', 'AFL', 'FRT',
#        'APH', 'ANSS', 'APH', 'AFL', 'AFL', 'CSCO', 'AMGN', 'CAG', 'AFL',
#        'AME', 'BWA', 'AMZN', 'AAPL', 'AAPL', 'GPC', 'FI', 'APH', 'BAC',
#        'AME', 'COP', 'APH', 'CFG', 'AFL', 'ALLE', 'COP', 'AFL', 'GD',
#        'AXP', 'ABT', 'ADP', 'GLW', 'APH', 'GIS', 'AFL', 'BKNG', 'GIS',
#        'CI', 'HWM', 'AFL', 'CME', 'DHR', 'AME', 'DOV', 'DIS', 'AMGN',
#        'ADI', 'AMZN', 'AVB', 'IP', 'IPG', 'A', 'DOV', 'CPT', 'APH', 'APH',
#        'AME', 'AMP', 'AME', 'APH', 'ETN', 'FI', 'AMGN', 'APH', 'BAC',
#        'CAG', 'HSY', 'CFG', 'APH', 'CAG', 'FRT', 'AMAT', 'CHD', 'CVX',
#        'JCI', 'CL', 'CPB', 'AFL', 'GD', 'DHI', 'ABT', 'GD', 'AME', 'APH',
#        'AMGN', 'GD', 'AEE', 'ALLE', 'AMAT', 'ALK', 'HLT', 'LW', 'AFL',
#        'BKNG', 'AME', 'AVB', 'AXP', 'ALLE', 'KO', 'ADI', 'CI', 'APH',
#        'GIS', 'ABT', 'AFL', 'CRM', 'AXP', 'MAS', 'HRL', 'APH', 'APH',
#        'AJG', 'DOV', 'AME', 'K', 'CI', 'ADM', 'CVX', 'KLAC', 'AMGN',
#        'DXCM', 'COP', 'BAC', 'MCO', 'AAPL', 'AME', 'CFG', 'ANSS', 'A',
#        'ADI', 'AAL', 'AME', 'AME', 'AEE', 'JNJ', 'AMZN', 'AEE', 'APH',
#        'GD', 'ANSS', 'AFL', 'AME', 'APH', 'BAC', 'FCX', 'AMD', 'DHI',
#        'CBRE', 'CBRE', 'ADI', 'FRT', 'APH', 'BDX', 'CVX', 'HON', 'KLAC',
#        'APH', 'AZO', 'APH', 'COP', 'ANSS', 'CMCSA', 'CDAY', 'ADP', 'AFL',
#        'AFL', 'ESS', 'AEE', 'HSY', 'ABBV', 'AFL', 'CHD', 'ALL', 'DOV',
#        'DHI', 'IP', 'CPT', 'KO', 'BAC', 'ALLE', 'DUK', 'EW', 'HD', 'AME',
#        'AEE', 'AFL', 'CPT', 'CVX', 'APH', 'APH', 'COP', 'AMZN', 'ADI',
#        'ADI', 'AAL', 'FRT', 'ABT', 'CFG', 'CFG', 'AMP', 'AXP', 'ABT',
#        'AME', 'AME', 'AME', 'DRI', 'AEE', 'AFL', 'A', 'AMT', 'APH', 'AFL',
#        'ANSS', 'AMCR', 'AMCR', 'CPB', 'COP', 'ETN', 'ANSS', 'AEE', 'FRT',
#        'AME', 'AEE', 'BDX', 'DD', 'BAC', 'APH', 'HRL', 'MAS', 'ADI',
#        'AXP', 'ABT', 'L', 'IBM', 'GL', 'APH', 'AME', 'A', 'APH', 'AMAT',
#        'CFG', 'BSX', 'CSCO', 'ETN', 'A', 'ADP', 'DD', 'KMI', 'APH', 'BEN',
#        'CB', 'COST', 'AAPL', 'KO', 'FTV', 'AKAM', 'ADI', 'APH', 'ANSS',
#        'AAL', 'AVB', 'HCA', 'APH', 'CI', 'CSX', 'DOV', 'AME', 'JPM',
#        'APH', 'APH', 'FRT', 'CVX', 'AME', 'FDS', 'ADP', 'AMGN', 'FRT',
#        'ABT', 'DUK', 'AME', 'A', 'AFL', 'DIS', 'AVGO', 'AEE', 'MAA',
#        'BAC', 'HD', 'AEE', 'CVX', 'COST', 'AFL', 'IP', 'DHR', 'AFL',
#        'AME', 'AMP', 'AEE', 'COP', 'COO', 'DOV', 'APH', 'ABT', 'AME',
#        'CMA', 'ABT'], dtype=object)
